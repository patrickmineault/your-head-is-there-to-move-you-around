# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

it = summary_iterator("../runs/Jan01_15-45-00_DESKTOP-I8HN3PB_pvc1_shallownet/events.out.tfevents.1609533900.DESKTOP-I8HN3PB.3117.0")
# Out:
# WARNING:tensorflow:From /home/pmin/anaconda3/envs/py3/lib/python3.8/site-packages/tensorflow/python/summary/summary_iterator.py:31: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
import tensorflow as tf
from tensorflow.python.summary.summary_iterator import summary_iterator
from tensorboard.plugins.hparams import plugin_data_pb2

si = summary_iterator(
    "../runs/Jan01_15-45-00_DESKTOP-I8HN3PB_pvc1_shallownet/1609533900.105029/events.out.tfevents.1609533900.DESKTOP-I8HN3PB.3117.1"
)

count = 0
for event in si:
    for value in event.summary.value:
        count += 1
        proto_bytes = value.metadata.plugin_data.content
        if len(proto_bytes) > 0:
            print('Found event!')
            
            plugin_data = plugin_data_pb2.HParamsPluginData.FromString(proto_bytes)
            print(plugin_data)
            if plugin_data.HasField("experiment"):
                print(
                    "Got experiment metadata with %d hparams and %d metrics"
                    % (
                        len(plugin_data.experiment.hparam_infos),
                        len(plugin_data.experiment.metric_infos),
                    ),
                )
            elif plugin_data.HasField("session_start_info"):
                print(
                    "Got session start info with concrete hparam values: %r"
                    % (dict(plugin_data.session_start_info.hparams),)
                )
# Out:
# Found event!
# experiment {
#   hparam_infos {
#     name: "exp_name"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "submodel"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "learning_rate"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "num_epochs"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "image_size"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "batch_size"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "nfeats"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "num_blocks"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "warmup"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "single_cell"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "ckpt_frequency"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "no_sample"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "no_wandb"
#     type: DATA_TYPE_FLOAT64
#   }
#   hparam_infos {
#     name: "load_conv1_weights"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "load_ckpt"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "dataset"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "data_root"
#     type: DATA_TYPE_STRING
#   }
#   hparam_infos {
#     name: "output_dir"
#     type: DATA_TYPE_STRING
#   }
# }
#
# Got experiment metadata with 18 hparams and 0 metrics
# Found event!
# session_start_info {
#   hparams {
#     key: "batch_size"
#     value {
#       number_value: 32.0
#     }
#   }
#   hparams {
#     key: "ckpt_frequency"
#     value {
#       number_value: 2500.0
#     }
#   }
#   hparams {
#     key: "data_root"
#     value {
#       string_value: "./data"
#     }
#   }
#   hparams {
#     key: "dataset"
#     value {
#       string_value: "pvc1"
#     }
#   }
#   hparams {
#     key: "exp_name"
#     value {
#       string_value: "_pvc1_shallownet"
#     }
#   }
#   hparams {
#     key: "image_size"
#     value {
#       number_value: 112.0
#     }
#   }
#   hparams {
#     key: "learning_rate"
#     value {
#       number_value: 0.01
#     }
#   }
#   hparams {
#     key: "load_ckpt"
#     value {
#       string_value: ""
#     }
#   }
#   hparams {
#     key: "load_conv1_weights"
#     value {
#       string_value: ""
#     }
#   }
#   hparams {
#     key: "nfeats"
#     value {
#       number_value: 64.0
#     }
#   }
#   hparams {
#     key: "no_sample"
#     value {
#       number_value: 0.0
#     }
#   }
#   hparams {
#     key: "no_wandb"
#     value {
#       number_value: 0.0
#     }
#   }
#   hparams {
#     key: "num_blocks"
#     value {
#       number_value: 0.0
#     }
#   }
#   hparams {
#     key: "num_epochs"
#     value {
#       number_value: 100.0
#     }
#   }
#   hparams {
#     key: "output_dir"
#     value {
#       string_value: "./models"
#     }
#   }
#   hparams {
#     key: "single_cell"
#     value {
#       number_value: -1.0
#     }
#   }
#   hparams {
#     key: "submodel"
#     value {
#       string_value: "shallownet_symmetric"
#     }
#   }
#   hparams {
#     key: "warmup"
#     value {
#       number_value: 10000.0
#     }
#   }
# }
#
# Got session start info with concrete hparam values: {'no_wandb': number_value: 0.0
# , 'num_blocks': number_value: 0.0
# , 'warmup': number_value: 10000.0
# , 'dataset': string_value: "pvc1"
# , 'learning_rate': number_value: 0.01
# , 'num_epochs': number_value: 100.0
# , 'ckpt_frequency': number_value: 2500.0
# , 'data_root': string_value: "./data"
# , 'load_ckpt': string_value: ""
# , 'exp_name': string_value: "_pvc1_shallownet"
# , 'batch_size': number_value: 32.0
# , 'no_sample': number_value: 0.0
# , 'nfeats': number_value: 64.0
# , 'submodel': string_value: "shallownet_symmetric"
# , 'output_dir': string_value: "./models"
# , 'single_cell': number_value: -1.0
# , 'load_conv1_weights': string_value: ""
# , 'image_size': number_value: 112.0
# }
# Found event!
# session_end_info {
#   status: STATUS_SUCCESS
# }

# %%
event
# Out:
# wall_time: 1609731694.9603016
# step: 8719456
# summary {
#   value {
#     tag: "Loss/train"
#     simple_value: 1.7002460956573486
#   }
# }
