# %%
import os

from python_dict_wrapper import wrap
import sys
sys.path.append('../')
from loaders import pvc4

import matplotlib.pyplot as plt

args = wrap({'data_root': '/mnt/e/data_derived',
             'image_size': 112,
             'single_cell': 0})

trainset = pvc4.PVC4(os.path.join(args.data_root, 'crcns-v2'), 
                                    split='train', 
                                    nt=32, 
                                    nx=args.image_size,
                                    ny=args.image_size,
                                    ntau=10, 
                                    nframedelay=0,
                                    single_cell=args.single_cell)
# Out:
# Loaded cell e0017

# %%
X, _, _, Y = trainset[0]
# Out:
# Using v2 infill

# %%
plt.plot(X.max(axis=2).values.max(axis=2).values.max(axis=0).values)

# %%
X.std()
# Out:
# tensor(0.9234)

# %%
plt.imshow(.25 * X[:, 40, :, :].permute((1, 2, 0)) + .5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
X
# Out:
# tensor([[[[-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           ...,
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356]],
#
#          [[ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           ...,
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932]],
#
#          [[ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           ...,
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449]],
#
#          ...,
#
#          [[ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           ...,
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496]],
#
#          [[ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           ...,
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630]],
#
#          [[ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           ...,
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890]]],
#
#
#         [[[-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           ...,
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356]],
#
#          [[ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           ...,
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932]],
#
#          [[ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           ...,
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449]],
#
#          ...,
#
#          [[ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           ...,
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496]],
#
#          [[ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           ...,
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630]],
#
#          [[ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           ...,
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890]]],
#
#
#         [[[-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           [-0.0352, -0.0352, -0.0352,  ..., -0.0345, -0.0345, -0.0345],
#           ...,
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356],
#           [-0.0375, -0.0375, -0.0375,  ..., -0.0356, -0.0356, -0.0356]],
#
#          [[ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           [ 0.8922,  0.8922,  0.8922,  ...,  0.8929,  0.8929,  0.8929],
#           ...,
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932],
#           [ 0.8853,  0.8853,  0.8853,  ...,  0.8932,  0.8932,  0.8932]],
#
#          [[ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           [ 1.1448,  1.1448,  1.1448,  ...,  1.1447,  1.1447,  1.1447],
#           ...,
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449],
#           [ 1.1381,  1.1381,  1.1381,  ...,  1.1449,  1.1449,  1.1449]],
#
#          ...,
#
#          [[ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4495,  0.4495,  0.4495,  ...,  0.4496,  0.4496,  0.4496],
#           ...,
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496],
#           [ 0.4452,  0.4452,  0.4452,  ...,  0.4496,  0.4496,  0.4496]],
#
#          [[ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           [ 0.5629,  0.5629,  0.5629,  ...,  0.5629,  0.5629,  0.5629],
#           ...,
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630],
#           [ 0.5559,  0.5559,  0.5559,  ...,  0.5630,  0.5630,  0.5630]],
#
#          [[ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           [ 0.0883,  0.0883,  0.0883,  ...,  0.0889,  0.0889,  0.0889],
#           ...,
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890],
#           [ 0.0838,  0.0838,  0.0838,  ...,  0.0890,  0.0890,  0.0890]]]])
